# %%
import pandas as pd

# %% [markdown]
# You can create a Pandas dataframe from a dictionary like seen below:

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Boston', 'Chicago', 'Denver', 'Seattle'],
    'Score': [85, 92, 78, 95, 89]
}

df = pd.DataFrame(data)

print("DataFrame from dictionary:")
print(df)

# %% [markdown]
# You can also create a pandas dataframe from a csv file, like seen below:

# %%
sales_df = pd.read_csv("files/students_record.csv")
print("The first 5 rows of the DataFrame")

print(sales_df.head())
