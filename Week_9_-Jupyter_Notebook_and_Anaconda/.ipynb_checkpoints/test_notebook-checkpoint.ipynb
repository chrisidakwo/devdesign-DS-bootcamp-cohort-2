# %%
print("Hello from Jupyter Notebook")
# Out:
# Hello from Jupyter Notebook

# %%
def multiply(a, b, c):
  return a * b * c

# %%
result = multiply(8, 3, 2)
print(result)
# Out:
# 48

# %%
location = input("Please enter your location: ")
print(f"The user currently stays in {location}")
